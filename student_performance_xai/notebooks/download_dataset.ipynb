# %%
from student_performance_xai.scripts.download_dataset import download_dataset

download_dataset()
# Out:
# Dataset URL: https://www.kaggle.com/datasets/larsen0966/student-performance-data-set
# License(s): CC0-1.0
# ...
#
# Dataset successfully downloaded!
# 100%|██████████| 12.1k/12.1k [00:00<00:00, 12.9MB/s]
