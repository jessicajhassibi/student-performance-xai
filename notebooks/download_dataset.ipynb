# %%
import os
import subprocess

PATH_TO_KAGGLE = "/Users/jessicahassibi/PycharmProjects/student-performance-xai/venv/bin/kaggle"
DATA = "larsen0966/student-performance-data-set"
DESTINATION = "../data/raw"


def download_dataset():
    os.makedirs(DESTINATION, exist_ok=True)

    command = [
        PATH_TO_KAGGLE,
        "datasets",
        "download",
        "-d", DATA,
        "-p", DESTINATION,
        "--unzip"
    ]

    subprocess.run(command, check=True)
    print("Dataset successfully downloaded!")

if __name__ == "__main__":
    download_dataset()
# Out:
# Dataset URL: https://www.kaggle.com/datasets/larsen0966/student-performance-data-set
# License(s): CC0-1.0
# Downloading student-performance-data-set.zip to ../data/raw
#
# Dataset successfully downloaded!
# 100%|██████████| 12.1k/12.1k [00:00<00:00, 14.8MB/s]
